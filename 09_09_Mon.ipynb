# %%
import random
import time

# 버블 정렬 함수
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# 퀵 정렬 함수
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# 합병 정렬 함수
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

# 메인 함수
def main():
    # 사용자로부터 입력 받기
    num_elements = int(input("생성할 랜덤 숫자의 개수를 입력하세요: "))

    # 랜덤 숫자 리스트 생성 및 정렬
    def generate_random_list(size):
        return random.sample(range(1, 1000), size)

    # 버블 정렬
    bubble_list = generate_random_list(num_elements)
    bubble_sort(bubble_list)
    bubble_time = measure_sorting_time(bubble_sort, num_elements)
    print("버블")
    print(f"{bubble_time:.10f} 초")
    print(bubble_list)
    print("\n")

    # 퀵 정렬
    quick_list = generate_random_list(num_elements)
    sorted_quick_list = quick_sort(quick_list)
    quick_time = measure_sorting_time(lambda arr: quick_sort(arr), num_elements)
    print("퀵")
    print(f"{quick_time:.10f} 초")
    print(sorted_quick_list)
    print("\n")

    # 합병 정렬
    merge_list = generate_random_list(num_elements)
    merge_sort(merge_list)
    merge_time = measure_sorting_time(merge_sort, num_elements)
    print("합병")
    print(f"{merge_time:.10f} 초")
    print(merge_list)
    print("\n")

if __name__ == "__main__":
    main()
# Out:
# 생성할 랜덤 숫자의 개수를 입력하세요: 100
# 버블
# 0.0041059000 초
# [5, 13, 21, 24, 27, 52, 55, 61, 65, 66, 69, 101, 109, 111, 121, 137, 143, 147, 155, 170, 187, 198, 200, 204, 211, 216, 220, 265, 287, 290, 303, 318, 319, 322, 336, 338, 339, 365, 367, 376, 378, 380, 389, 398, 405, 410, 416, 427, 457, 478, 481, 488, 497, 500, 503, 526, 527, 532, 536, 543, 547, 566, 583, 593, 608, 612, 614, 634, 644, 647, 648, 659, 666, 671, 681, 694, 695, 710, 735, 736, 737, 738, 751, 790, 799, 845, 847, 853, 862, 864, 878, 881, 919, 927, 933, 943, 967, 972, 981, 990]
#
#
# 퀵
# 0.0015055000 초
# ...
